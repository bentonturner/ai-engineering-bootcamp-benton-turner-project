# %% [markdown]
# ### Import Dependencies

# %%
from pydantic import BaseModel

from langsmith import traceable, get_current_run_tree

import instructor

from langgraph.graph import StateGraph, START, END
from langgraph.prebuilt import ToolNode
from langgraph.types import Send

from langchain_core.messages import SystemMessage
from IPython.display import Image, display

from typing import Literal, Dict, Any, Annotated, List
from pydantic import Field
from operator import add

import random
import openai
import pandas as pd

from jinja2 import Template

from qdrant_client import QdrantClient
from qdrant_client import models
from qdrant_client.models import VectorParams, Distance, SparseVectorParams, Modifier, PayloadSchemaType, PointStruct, Document, Prefetch, FusionQuery

# %% [markdown]
# ### Query Expansion (Parallel Execution)

# %%
class State(BaseModel):
    expanded_query: List[str] = []
    retrieved_context: Annotated[List[str], add] = []
    initial_query: str = ""
    answer: str = ""
    question_relevant: bool = False
    query: str = ""
    k: int = 10

# %% [markdown]
# ### Query Expansion / Rewriting Node

# %%
class QueryExpandResponse(BaseModel):
    statements: List[str]

# %%
@traceable(
    name="query_expansion",
    run_type="llm",
    metadata={
        "ls_provider": "openai",
        "ls_model_name": "gpt-5.4-mini"
    }
)
def query_expansion_node(state: State) -> dict:

    prompt_template = """You are a query expansion module in a shopping assistant. Your job is to rewrite a customer's query into distinct statements for semantic product search.

## Instructions

- Expand the question into 1-5 concise statements.
- Each statement should capture a separate product or attribute from the query.
- Use natural product-description language.
- Do not produce multiple statements that express the same intent.

## Examples

Question: "Name me a good summer song and a relaxing jazz album"
Statements:
- "Upbeat summer song"
- "Relaxing jazz album"

Question: "What's a good road trip album for the family?"
Statements:
- "Family-friendly road trip album"

Question: "Do you have any Queen albums?"
Statements:
- "Queen albums"

<question>
{{ query }}
</question>
"""

    template = Template(prompt_template)

    prompt = template.render(
        query=state.initial_query
    )

    client = instructor.from_provider(
        "openai/gpt-5.4-mini",
        mode=instructor.Mode.RESPONSES_TOOLS
    )

    response, raw_response = client.create_with_completion(
        messages=[
            {"role": "system", "content": prompt}
        ],
        reasoning={"effort": "none"},
        response_model=QueryExpandResponse
    )

    return {
        "expanded_query": response.statements
    }

# %%
def query_expand_conditional_edges(state: State) -> dict:

    send_messages = []

    for query in state.expanded_query:
        send_messages.append(
            Send(
                "retriever_node",
                {
                    "query": query,
                    "k": state.k
                }
            )
        )

    return send_messages

# %% [markdown]
# ### Retriever Node

# %%
@traceable(
    name="embed_query",
    run_type="embedding",
    metadata={
        "ls_provider": "openai",
        "ls_model_name": "text-embedding-3-small"
    }
)
def get_embedding(text, model="text-embedding-3-small"):
    response = openai.embeddings.create(
        input=text,
        model=model
    )

    current_run = get_current_run_tree()
    if current_run:
        current_run.metadata["usage_metadata"] = {
            "input_tokens": response.usage.prompt_tokens,
            "total_tokens": response.usage.total_tokens,
        }

    return response.data[0].embedding


@traceable(
    name="retrieve_data",
    run_type="retriever"
)
def retriever_node(state: State) -> dict:

    hybrid = True

    qdrant_client = QdrantClient(url="http://127.0.0.1:6333")

    query_embedding = get_embedding(state["query"])

    if hybrid:
        results = qdrant_client.query_points(
            collection_name="Amazon-items-collection-01-hybrid-search",
            prefetch=[
                Prefetch(
                    query=query_embedding,
                    using="text-embedding-3-small",
                    limit=20
                ),
                Prefetch(
                    query=Document(
                        text=state["query"],
                        model="qdrant/bm25"
                    ),
                    using="bm25",
                    limit=20
                )
            ],
            query=models.RrfQuery(rrf=models.Rrf(weights=[3,1])),
            limit=state["k"]
        )
    else:
        results = qdrant_client.query_points(
            collection_name="Amazon-items-collection-01-hybrid-search",
            query=query_embedding,
            using="text-embedding-3-small",
            limit=state["k"]
        )

    retrieved_context_ids = []
    retrieved_context = []
    similarity_scores = []
    retrieved_context_ratings = []

    for result in results.points:
        retrieved_context_ids.append(result.payload["parent_asin"])
        retrieved_context.append(result.payload["preprocessed_description"])
        similarity_scores.append(result.score)
        retrieved_context_ratings.append(result.payload["average_rating"])

    formatted_context = ""

    for id, chunk, rating in zip(retrieved_context_ids, retrieved_context, retrieved_context_ratings):
        formatted_context += f"- ID: {id}, rating: {rating}, description: {chunk}\n"

    return {
        "retrieved_context": [formatted_context]
    }

# %% [markdown]
# ### Aggregator Node

# %%
class AggregatorResponse(BaseModel):
    answer: str

# %%
@traceable(
    name="generate_answer",
    run_type="llm",
    metadata={
        "ls_provider": "openai",
        "ls_model_name": "gpt-5.4-mini"
    }
)
def aggregator_node(state: State) -> dict:

    preprocessed_context = "\n".join(state.retrieved_context)

    prompt_template = """You are a shopping assistant that can answer questions about the products in stock.

You will be given a question and a list of context.

### Instructions

- You need to answer the question based on the provided context only.
- Never use word context and refer to it as the available products.
- The answer to the question should contain detailed information about the product and returned with detailed specification in bullet points.

### Context

{{ preprocessed_context }}

### Question

{{ question }}
"""

    template = Template(prompt_template)

    prompt = template.render(
        preprocessed_context=preprocessed_context,
        question=state.initial_query
    )

    client = instructor.from_provider(
        "openai/gpt-5.4-mini",
        mode=instructor.Mode.RESPONSES_TOOLS
    )

    response, raw_response = client.create_with_completion(
        messages=[
            {"role": "system", "content": prompt}
        ],
        reasoning={"effort": "none"},
        response_model=AggregatorResponse
    )

    return {
        "answer": response.answer
    }

# %% [markdown]
# ### User Intent Router Node

# %%
class IntentRouterResponse(BaseModel):
    question_relevant: bool
    answer: str = Field(description="An answer to the question if the users question is not relevant to music products.")

# %%
@traceable(
    name="route_intent",
    run_type="llm",
    metadata={
        "ls_provider": "openai",
        "ls_model_name": "gpt-5.4-mini"
    }
)
def intent_router_node(state: State) -> dict:

    prompt_template = """You are a relevance router for a shopping assistant that answers questions about music products in stock.

## Instructions

- Determine whether the question is about music products, inventory, or purchasing.
- Questions about music product features, availability, pricing, comparisons, and recommendations are relevant.
- Questions about store policies, personal advice, or unrelated topics are not relevant.

## Examples

Question: "Name me a good summer song"
Relevant: yes

Question: "What's the weather like today?"
Relevant: no - not related to music products

Question: "Can you help me write an essay?"
Relevant: no - not related to music products

Question: "Do you have any Queen albums under $30?"
Relevant: yes

Question: "What's your return policy?"
Relevant: no - about store policy, not music product information

<question>
{{ query }}
</question>
"""

    template = Template(prompt_template)

    prompt = template.render(
        query=state.initial_query
    )

    client = instructor.from_provider(
        "openai/gpt-5.4-mini",
        mode=instructor.Mode.RESPONSES_TOOLS
    )

    response, raw_response = client.create_with_completion(
        messages=[
            {"role": "system", "content": prompt}
        ],
        reasoning={"effort": "none"},
        response_model=IntentRouterResponse
    )

    return {
        "question_relevant": response.question_relevant,
        "answer": response.answer
    }

# %%
def intent_router_conditional_edges(state: State) -> str:

    if state.question_relevant:
        return "query_expansion_node"
    else:
        return "end"

# %% [markdown]
# ### Grapg Construction

# %%
workflow = StateGraph(State)

workflow.add_node("query_expansion_node", query_expansion_node)
workflow.add_node("retriever_node", retriever_node)
workflow.add_node("aggregator_node", aggregator_node)
workflow.add_node("intent_router_node", intent_router_node)

workflow.add_edge(START, "intent_router_node")

workflow.add_conditional_edges(
    "intent_router_node",
    intent_router_conditional_edges,
    {
        "query_expansion_node": "query_expansion_node",
        "end": END
    }
)

workflow.add_conditional_edges(
    "query_expansion_node",
    query_expand_conditional_edges
)

workflow.add_edge("retriever_node", "aggregator_node")
workflow.add_edge("aggregator_node", END)

graph = workflow.compile()

# %%
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
initial_state = {
    "initial_query": "Name me a good summer song and a road trip album for the family"
}

# %%
result = graph.invoke(initial_state)
# Out:
# /Users/bentonturner/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/qdrant_client/qdrant_remote.py:290: UserWarning: Failed to obtain server version. Unable to check client-server compatibility. Set check_compatibility=False to skip version check.
#   show_warning(
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/httpcore/_backends/sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File /opt/homebrew/Cellar/python@3.12/3.12.13/Frameworks/Python.framework/Versions/3.12/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 8] nodename nor servname provided, or not known
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/qdrant_client/http/api_client.py:134, in ApiClient.send_inner(self, request)
#     133 try:
# --> 134     response = self._client.send(request)
#     135 except Exception as e:
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.13/Frameworks/Python.framework/Versions/3.12/lib/python3.12/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# ResponseHandlingException                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 result = graph.invoke(initial_state)
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/langgraph/pregel/main.py:3880, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3877             chunks.append(chunk)
#    3878 else:
#    3879     # v1: collect interrupts from updates stream
# -> 3880     for chunk in self.stream(
#    3881         input,
#    3882         config,
#    3883         context=context,
#    3884         stream_mode=(
#    3885             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3886         ),
#    3887         print_mode=print_mode,
#    3888         output_keys=output_keys,
#    3889         interrupt_before=interrupt_before,
#    3890         interrupt_after=interrupt_after,
#    3891         durability=durability,
#    3892         control=control,
#    3893         **kwargs,
#    3894     ):
#    3895         if stream_mode == "values":
#    3896             if len(chunk) == 2:
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/langgraph/pregel/main.py:2936, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2934 for task in loop.match_cached_writes():
#    2935     loop.output_writes(task.id, task.writes, cached=True)
# -> 2936 for _ in runner.tick(
#    2937     [t for t in loop.tasks.values() if not t.writes],
#    2938     timeout=self.step_timeout,
#    2939     get_waiter=get_waiter,
#    2940     schedule_task=loop.accept_push,
#    2941 ):
#    2942     # emit output
#    2943     yield from _output(
#    2944         stream_mode,
#    2945         print_mode,
#    (...)   2951         _state_mapper,
#    2952     )
#    2953 loop.after_tick()
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/langgraph/pregel/_runner.py:344, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     342 # panic on failure or timeout
#     343 try:
# --> 344     _panic_or_proceed(
#     345         futures.done.union(f for f, t in futures.items() if t is not None),
#     346         panic=reraise,
#     347         handled_exception_ids=self._handled_exception_ids,
#     348         handled_futures=handled_futures,
#     349     )
#     350 except Exception as exc:
#     351     if tb := exc.__traceback__:
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/langgraph/pregel/_runner.py:687, in _panic_or_proceed(futs, timeout_exc_cls, panic, handled_exception_ids, handled_futures)
#     685                 interrupts.append(exc)
#     686             elif fut not in SKIP_RERAISE_SET:
# --> 687                 raise exc
#     688 # raise combined interrupts
#     689 if interrupts:
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/langgraph/pregel/_executor.py:80, in BackgroundExecutor.done(self, task)
#      78 """Remove the task from the tasks dict when it's done."""
#      79 try:
# ---> 80     task.result()
#      81 except GraphBubbleUp:
#      82     # This exception is an interruption signal, not an error
#      83     # so we don't want to re-raise it on exit
#      84     self.tasks.pop(task)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.13/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.13/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /opt/homebrew/Cellar/python@3.12/3.12.13/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/langgraph/pregel/_retry.py:585, in run_with_retry(task, retry_policy, configurable)
#     583     task.writes.clear()
#     584     # run the task
# --> 585     return task.proc.invoke(task.input, config)
#     586 except ParentCommand as exc:
#     587     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:684, in RunnableSeq.invoke(self, input, config, **kwargs)
#     682     # run in context
#     683     with set_config_context(config, run) as context:
# --> 684         input = context.run(step.invoke, input, config, **kwargs)
#     685 else:
#     686     input = step.invoke(input, config)
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:426, in RunnableCallable.invoke(self, input, config, **kwargs)
#     424         run_manager.on_chain_end(ret)
#     425 else:
# --> 426     ret = self.func(*args, **kwargs)
#     427 if self.recurse and isinstance(ret, Runnable):
#     428     return ret.invoke(input, config)
#
# Cell In[32], line 38, in retriever_node(state)
#      34
#      35     query_embedding = get_embedding(state["query"])
#      36
#      37     if hybrid:
# ---> 38         results = qdrant_client.query_points(
#      39             collection_name="Amazon-items-collection-01-hybrid-search",
#      40             prefetch=[
#      41                 Prefetch(
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/qdrant_client/qdrant_client.py:423, in QdrantClient.query_points(self, collection_name, query, using, prefetch, query_filter, search_params, limit, offset, with_payload, with_vectors, score_threshold, lookup_from, consistency, shard_key_selector, timeout, **kwargs)
#     408         else:
#     409             prefetch = (
#     410                 next(
#     411                     iter(
#    (...)    420                 else None
#     421             )
# --> 423 return self._client.query_points(
#     424     collection_name=collection_name,
#     425     query=query,
#     426     prefetch=prefetch,
#     427     query_filter=query_filter,
#     428     search_params=search_params,
#     429     limit=limit,
#     430     offset=offset,
#     431     with_payload=with_payload,
#     432     with_vectors=with_vectors,
#     433     score_threshold=score_threshold,
#     434     using=using,
#     435     lookup_from=lookup_from,
#     436     consistency=consistency,
#     437     shard_key_selector=shard_key_selector,
#     438     timeout=timeout,
#     439     **kwargs,
#     440 )
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/qdrant_client/qdrant_remote.py:585, in QdrantRemote.query_points(self, collection_name, query, using, prefetch, query_filter, search_params, limit, offset, with_payload, with_vectors, score_threshold, lookup_from, consistency, shard_key_selector, timeout, **kwargs)
#     568     lookup_from = GrpcToRest.convert_lookup_location(lookup_from)
#     570 query_request = models.QueryRequest(
#     571     shard_key=shard_key_selector,
#     572     prefetch=prefetch,
#    (...)    582     lookup_from=lookup_from,
#     583 )
# --> 585 query_result = self.http.search_api.query_points(
#     586     collection_name=collection_name,
#     587     consistency=consistency,
#     588     timeout=timeout,
#     589     query_request=query_request,
#     590 )
#     592 result: models.QueryResponse | None = query_result.result
#     593 assert result is not None, "Search returned None"
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/qdrant_client/http/api/search_api.py:783, in SyncSearchApi.query_points(self, collection_name, consistency, timeout, query_request)
#     773 def query_points(
#     774     self,
#     775     collection_name: str,
#    (...)    778     query_request: m.QueryRequest = None,
#     779 ) -> m.InlineResponse20024:
#     780     """
#     781     Universally query points. This endpoint covers all capabilities of search, recommend, discover, filters. But also enables hybrid and multi-stage queries.
#     782     """
# --> 783     return self._build_for_query_points(
#     784         collection_name=collection_name,
#     785         consistency=consistency,
#     786         timeout=timeout,
#     787         query_request=query_request,
#     788     )
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/qdrant_client/http/api/search_api.py:181, in _SearchApi._build_for_query_points(self, collection_name, consistency, timeout, query_request)
#     179 if "Content-Type" not in headers:
#     180     headers["Content-Type"] = "application/json"
# --> 181 return self.api_client.request(
#     182     type_=m.InlineResponse20024,
#     183     method="POST",
#     184     url="/collections/{collection_name}/points/query",
#     185     headers=headers if headers else None,
#     186     path_params=path_params,
#     187     params=query_params,
#     188     content=body,
#     189 )
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/qdrant_client/http/api_client.py:95, in ApiClient.request(self, type_, method, url, path_params, **kwargs)
#      93     kwargs["timeout"] = int(kwargs["params"]["timeout"])
#      94 request = self._client.build_request(method, url, **kwargs)
# ---> 95 return self.send(request, type_)
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/qdrant_client/http/api_client.py:112, in ApiClient.send(self, request, type_)
#     111 def send(self, request: Request, type_: Type[T]) -> T:
# --> 112     response = self.middleware(request, self.send_inner)
#     114     if response.status_code == 429:
#     115         retry_after_s = response.headers.get("Retry-After", None)
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/qdrant_client/http/api_client.py:149, in ApiClient.add_middleware.<locals>.new_middleware(request, call_next)
#     146 def inner_send(request: Request) -> Response:
#     147     return current_middleware(request, call_next)
# --> 149 return middleware(request, inner_send)
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/qdrant_client/context_headers.py:39, in rest_headers_middleware(request, call_next)
#      37 for key, value in get_context_headers().items():
#      38     request.headers[key] = value
# ---> 39 return call_next(request)
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/qdrant_client/http/api_client.py:147, in ApiClient.add_middleware.<locals>.new_middleware.<locals>.inner_send(request)
#     146 def inner_send(request: Request) -> Response:
# --> 147     return current_middleware(request, call_next)
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/qdrant_client/http/api_client.py:250, in BaseMiddleware.__call__(self, request, call_next)
#     249 def __call__(self, request: Request, call_next: Send) -> Response:
# --> 250     return call_next(request)
#
# File ~/Documents/GitHub/ai-engineering-bootcamp-cohort-5/.venv/lib/python3.12/site-packages/qdrant_client/http/api_client.py:136, in ApiClient.send_inner(self, request)
#     134     response = self._client.send(request)
#     135 except Exception as e:
# --> 136     raise ResponseHandlingException(e)
#     137 return response
#
# ResponseHandlingException: [Errno 8] nodename nor servname provided, or not known
# During task with name 'retriever_node' and id '24929281-41b1-a46a-5dfd-ddacaf141033'

# %%
result
# Out:
# {'retrieved_context': [],
#  'initial_query': 'Name me a good summer song and a road trip album for the family',
#  'answer': 'I can help with product-related questions like availability, pricing, or recommendations. For a good summer song and road trip album, I’d suggest asking a music assistant or sharing your taste so I can help with general recommendations.',
#  'question_relevant': False}

# %%
print(result["answer"])
# Out:
# I can help with product and shopping-related questions like availability, pricing, and recommendations. Your request is about songs and music recommendations, so it isn’t related to products in stock.

# %%
initial_state = {
    "initial_query": "How many times should I be walking my dog per day?"
}

# %%
result = graph.invoke(initial_state)

# %%
result
# Out:
# {'retrieved_context': [],
#  'initial_query': 'How many times should I be walking my dog per day?',
#  'answer': 'How many times you should walk your dog per day is a pet care question, not a question about products, inventory, or purchasing.',
#  'question_relevant': False}
