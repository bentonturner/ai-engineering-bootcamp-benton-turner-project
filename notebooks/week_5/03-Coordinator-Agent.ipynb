# %% [markdown]
# ### Import Dependencies

# %%
from pydantic import BaseModel

from langchain_openai import ChatOpenAI

from langsmith import traceable

import instructor

from langgraph.graph import StateGraph, START, END
from langgraph.prebuilt import ToolNode


from langchain_core.messages import SystemMessage, convert_to_openai_messages, HumanMessage, AIMessage, ToolMessage
from IPython.display import Image, display

from typing import Any, Annotated, List
from pydantic import Field
from operator import add

from jinja2 import Template

from utils.tools import get_formatted_item_context, get_formatted_reviews_context, get_shopping_cart, remove_from_cart, add_to_shopping_cart

# %% [markdown]
# ### Message History Sanitizer
#
# Every agent below replays the full conversation history back to the model. If a run is
# interrupted between a tool call and its result, the checkpoint keeps an `AIMessage` with
# `tool_calls` but no matching `ToolMessage`, and the OpenAI API rejects every later run on
# that thread with `No tool output found for function call ...`.
#
# `drop_orphan_tool_calls` removes both halves of any incomplete pair, so an already-damaged
# thread stays usable without deleting its history.

# %%
def drop_orphan_tool_calls(messages):
    """Drop tool calls and tool results that have no counterpart in the history."""

    answered = {m.tool_call_id for m in messages if isinstance(m, ToolMessage)}

    kept = []
    for message in messages:
        call_ids = [tc.get("id") for tc in (getattr(message, "tool_calls", None) or [])]
        if call_ids and not answered.issuperset(call_ids):
            continue
        kept.append(message)

    live_call_ids = {
        tc.get("id")
        for m in kept
        for tc in (getattr(m, "tool_calls", None) or [])
    }

    return [
        m for m in kept
        if not isinstance(m, ToolMessage) or m.tool_call_id in live_call_ids
    ]

# %% [markdown]
# ## Worker Agents

# %% [markdown]
# ### Product QnA Agent

# %%
class RAGUsedContext(BaseModel):
    id: str = Field(description="ID of the item used to answer the question")
    description: str = Field(description="Description of the item used to answer the question")

class FinalQnAAgentResponse(BaseModel):

    """Call this tool when the final answer is possible using available context."""

    answer: str = Field(description="Answer to the question")
    references: list[RAGUsedContext] = Field(description="List of items used to answer the question")

# %%
@traceable(
    name="product_qna_agent",
    run_type="llm",
    metadata={
        "ls_provider": "openai",
        "ls_model_name": "gpt-5.4-mini"
    }
)
def product_qna_agent(state) -> dict:
    
    prompt_template = """You are a shopping assistant answering customer questions about products in stock.

## Procedure

Before every tool call, check what previous tool calls in this conversation already
returned. Search only for what's genuinely missing. If nothing is missing, call
FinalResponse instead — previously retrieved data is as valid as fresh data, and
re-running a search you already ran is an error.

Customer: "Which of those speakers is cheapest?"
→ Speakers and prices already retrieved. No search. FinalResponse.

Customer: "Does that jacket come with a rain shell, and do you have gloves?"
→ Jacket specs already retrieved; gloves are not. Search gloves only.

## Answering

- Never state a product detail that isn't in the retrieved data.
- Describe products with specifications in bullet points.
- In references, include every chunk that contributed to your answer with the chunk id and product name.
- Call retrieved data "available products", never "context".
- Nothing relevant returned → say so, ask the customer to refine.
- Off-topic question → ask what product they're interested in.
"""

    template = Template(prompt_template)

    prompt = template.render()

    llm = ChatOpenAI(
        model="gpt-5.4-mini",
        reasoning_effort="low",
        use_responses_api=True
    )
    llm_with_tools = llm.bind_tools(
        [get_formatted_item_context, get_formatted_reviews_context, FinalQnAAgentResponse],
        tool_choice="required"
    )

    response = llm_with_tools.invoke(
        [
            SystemMessage(content=prompt),
            *drop_orphan_tool_calls(state.messages)
        ]
    )

    final_answer = False
    answer = ""
    references = []

    def sanitise_response(response):

        for tool_call in response.tool_calls:
            if tool_call.get("name") == "FinalQnAAgentResponse":
                answer = tool_call.get("args").get("answer")

        return AIMessage(content=answer)

    if len(response.tool_calls) > 0:
        for tool_call in response.tool_calls:
            if tool_call.get("name") == "FinalQnAAgentResponse":
                final_answer = True
                answer = tool_call.get("args").get("answer")
                references.extend(tool_call.get("args").get("references"))

                response = sanitise_response(response)

    return {
        "messages": [response],
        "product_qna_agent": {
            "iteration": state.product_qna_agent.iteration + 1,
            "final_answer": final_answer
        },
        "answer": answer,
        "references": references
    }

# %% [markdown]
# ### Shopping Cart Agent

# %%
class FinalAgentResponse(BaseModel):

    answer: str = Field(description="Answer to the question")

# %%
@traceable(
    name="shopping_cart_agent",
    run_type="llm",
    metadata={
        "ls_provider": "openai",
        "ls_model_name": "gpt-5.4-mini"
    }
)
def shopping_cart_agent(state) -> dict:
    
    prompt_template = """You are a part of the shopping assistant that can manage the user's shopping cart.

## Instructions

- Use names specificly provided in the available tools. Don't add any additional text to the names.
- You can run multipple tools at once.
- As the final answer you should return an answer in a form of actions performed.

## Additional information about the user

- User ID: {{ user_id }}
- Cart ID: {{ cart_id }}
"""

    template = Template(prompt_template)

    prompt = template.render(
        user_id=state.user_id,
        cart_id=state.cart_id
    )

    llm = ChatOpenAI(
        model="gpt-5.4-mini",
        reasoning_effort="low",
        use_responses_api=True
    )
    llm_with_tools = llm.bind_tools(
        [get_shopping_cart, remove_from_cart, add_to_shopping_cart, FinalAgentResponse],
        tool_choice="required"
    )

    response = llm_with_tools.invoke(
        [
            SystemMessage(content=prompt),
            *drop_orphan_tool_calls(state.messages)
        ]
    )

    final_answer = False
    answer = ""

    def sanitise_response(response):

        for tool_call in response.tool_calls:
            if tool_call.get("name") == "FinalAgentResponse":
                answer = tool_call.get("args").get("answer")

        return AIMessage(content=answer)

    if len(response.tool_calls) > 0:
        for tool_call in response.tool_calls:
            if tool_call.get("name") == "FinalAgentResponse":
                final_answer = True
                answer = tool_call.get("args").get("answer")

                response = sanitise_response(response)

    return {
        "messages": [response],
        "shopping_cart_agent": {
            "iteration": state.shopping_cart_agent.iteration + 1,
            "final_answer": final_answer
        },
        "answer": answer
    }

# %% [markdown]
# ## Coordinator Agent

# %%
class Delegation(BaseModel):
    agent: str = Field(description="The agent to delegate the task to.")
    task: str = Field(description="The task to be performed by the agent.")

class Plan(BaseModel):
    next_agent: str = Field(description="The next agent to invoke")
    plan: List[Delegation] = Field(description="A list of delegations to agents with tasks to be performed in sequence.")

# %%
@traceable(
    name="coordinator_agent",
    run_type="llm",
    metadata={
        "ls_provider": "openai",
        "ls_model_name": "gpt-5.4-mini"
    }
)
def coordinator_agent(state) -> dict:
    
    prompt_template = """You are a Coordinator Agent as part of a shopping assistant.

## Instructions

- Your role is to create plans for solving user queries and delegate the tasks accordingly.
- You will be given a conversation history, your task is to create a plan for solving the user's query.
- After the plan is created, you should output the next agent to invoke and the task to be performed by that agent.
- Once an agent finishes its task, you will be handed the control back, you should then review the conversation history and revise the plan.
- If there is a sequence of tasks to be performed by a single agent, you should combine them into a single task.
- Do not route to any agent if the user's query needs clarification or is irelevant. Do it yourself.

## Available Agents

- product_qna_agent: The user is asking a question about a product. This can be a question about available products, their specifications, user reviews etc.
- shopping_cart_agent: The user is asking to add or remove items from the shopping cart or questions about the current shopping cart.

## Examples

Question: "Do you have running shoes under $100?"
Next agent: product_qna_agent

Question: "Can you list the items in my cart?"
Next agent: shopping_cart_agent
"""

    template = Template(prompt_template)

    prompt = template.render()

    llm = ChatOpenAI(
        model="gpt-5.4-mini",
        reasoning_effort="low",
        use_responses_api=True
    )
    llm_with_tools = llm.bind_tools(
        [FinalAgentResponse, Plan],
        tool_choice="required"
    )

    response = llm_with_tools.invoke(
        [
            SystemMessage(content=prompt),
            *drop_orphan_tool_calls(state.messages)
        ]
    )

    final_answer = False
    answer = ""
    plan = []
    next_agent = ""

    def sanitise_response(response):

        for tool_call in response.tool_calls:
            if tool_call.get("name") == "FinalAgentResponse":
                answer = tool_call.get("args").get("answer")

        return AIMessage(content=answer)

    if len(response.tool_calls) > 0:
        if response.tool_calls[0].get("name") == "Plan":
            plan = response.tool_calls[0].get("args").get("plan")
            next_agent = response.tool_calls[0].get("args").get("next_agent")
            response = None
        else:
            for tool_call in response.tool_calls:
                if tool_call.get("name") == "FinalAgentResponse":
                    final_answer = True
                    answer = tool_call.get("args").get("answer")

                    response = sanitise_response(response)

    return {
        "messages": [response] if response else [],
        "coordinator_agent": {
            "iteration": state.coordinator_agent.iteration + 1,
            "final_answer": final_answer,
            "plan": plan,
            "next_agent": next_agent
        },
        "answer": answer
    }

# %% [markdown]
# ### Router Nodes

# %%
def product_qna_agent_tool_router(state) -> str:

    if state.product_qna_agent.final_answer:
        return "end"
    elif state.product_qna_agent.iteration > 5:
        return "end"
    elif len(state.messages[-1].tool_calls) > 0:
        return "tools"
    else:
        return "end"

# %%
def shopping_cart_agent_tool_router(state) -> str:

    if state.shopping_cart_agent.final_answer:
        return "end"
    elif state.shopping_cart_agent.iteration > 4:
        return "end"
    elif len(state.messages[-1].tool_calls) > 0:
        return "tools"
    else:
        return "end"

# %%
def coordinator_agent_edge(state) -> str:

    if state.coordinator_agent.final_answer:
        return "end"
    elif state.coordinator_agent.iteration > 4:
        return "end"
    elif state.coordinator_agent.next_agent == "product_qna_agent":
        return "product_qna_agent"
    elif state.coordinator_agent.next_agent == "shopping_cart_agent":
        return "shopping_cart_agent"
    else:
        return "end"

# %% [markdown]
# ### Graph Construction

# %%
class AgentProperties(BaseModel):
    iteration: int = 0
    final_answer: bool = False

class CoordinatorAgentProperties(BaseModel):
    iteration: int = 0
    final_answer: bool = False
    plan: List[Delegation] = []
    next_agent: str = ""
    
class State(BaseModel):
    messages: Annotated[List[Any], add] = []
    user_intent: str = ""
    product_qna_agent: AgentProperties = AgentProperties()
    shopping_cart_agent: AgentProperties = AgentProperties()
    coordinator_agent: CoordinatorAgentProperties = CoordinatorAgentProperties()
    answer: str = ""
    references: list[RAGUsedContext] = []
    user_id: str = ""
    cart_id: str = ""

# %%
workflow = StateGraph(State)

product_qna_agent_tools = [get_formatted_item_context, get_formatted_reviews_context]
product_qna_agent_tool_node = ToolNode(product_qna_agent_tools, handle_tool_errors=True)

shopping_cart_agent_tools = [get_shopping_cart, remove_from_cart, add_to_shopping_cart]
shopping_cart_agent_tool_node = ToolNode(shopping_cart_agent_tools, handle_tool_errors=True)

workflow.add_node("product_qna_agent_tool_node", product_qna_agent_tool_node)
workflow.add_node("shopping_cart_agent_tool_node", shopping_cart_agent_tool_node)
workflow.add_node("product_qna_agent", product_qna_agent)
workflow.add_node("shopping_cart_agent", shopping_cart_agent)
workflow.add_node("coordinator_agent", coordinator_agent)

workflow.add_edge(START, "coordinator_agent")

workflow.add_conditional_edges(
    "coordinator_agent",
    coordinator_agent_edge,
    {
        "product_qna_agent": "product_qna_agent",
        "shopping_cart_agent": "shopping_cart_agent",
        "end": END
    }
)

workflow.add_conditional_edges(
    "product_qna_agent",
    product_qna_agent_tool_router,
    {
        "tools": "product_qna_agent_tool_node",
        "end": "coordinator_agent"
    }
)

workflow.add_conditional_edges(
    "shopping_cart_agent",
    shopping_cart_agent_tool_router,
    {
        "tools": "shopping_cart_agent_tool_node",
        "end": "coordinator_agent"
    }
)

workflow.add_edge("product_qna_agent_tool_node", "product_qna_agent")
workflow.add_edge("shopping_cart_agent_tool_node", "shopping_cart_agent")

graph = workflow.compile()

# %%
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ## Test the Agent

# %%
from langgraph.checkpoint.postgres import PostgresSaver

# %% [markdown]
# ### Prerequisites
#
# Run these once before the demos below.
#
# - **Checkpoint tables** — `checkpointer.setup()` creates them; without it you get
#   `UndefinedTable: relation "checkpoints" does not exist`.
# - **Shopping cart table** — apply `scripts/sql/shopping_cart_table.sql`.
# - **Reviews collection** — run `notebooks/week_4/02-Multiple-Tools.ipynb` to build
#   `Amazon-reviews-collection-01`, otherwise review lookups return a "not available" message.
#
# Each demo below reuses its `thread_id`, so re-running a cell appends to that conversation
# rather than starting over. Call `clear_thread_checkpoint(thread_id)` when you want a fresh start.

# %%
CHECKPOINT_DB_URI = "postgresql://langgraph_user:langgraph_password@localhost:5433/langgraph_db"

with PostgresSaver.from_conn_string(CHECKPOINT_DB_URI) as checkpointer:
    checkpointer.setup()

# %%
import psycopg

def clear_thread_checkpoint(thread_id: str) -> None:
    """Wipe a thread's saved history so the next run starts a fresh conversation."""

    with psycopg.connect(CHECKPOINT_DB_URI) as conn:
        with conn.cursor() as cur:
            for table in ("checkpoints", "checkpoint_writes", "checkpoint_blobs"):
                cur.execute(f"DELETE FROM {table} WHERE thread_id = %s", (thread_id,))
        conn.commit()

    print(f"Cleared checkpoints for thread {thread_id}")

# %% [markdown]
# ### Multiturn Conversation

# %%
initial_state = {
    "messages": [HumanMessage(content="What is the weather today?")]
}
config = {
    "configurable": {
        "thread_id": "0000000000002000"
    }
}

with PostgresSaver.from_conn_string(
    "postgresql://langgraph_user:langgraph_password@localhost:5433/langgraph_db"
) as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["values"]
    ):
        result_1 = chunk[1]

# %%
result_1
# Out:
# {'messages': [HumanMessage(content='What is the weather today?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='I’m sorry, but I can’t help with today’s weather here.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#   HumanMessage(content='What is the weather today?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='I’m sorry, but I can’t provide today’s weather here.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#   HumanMessage(content='What is the weather today?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='I’m sorry, but I can’t provide today’s weather here.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#   HumanMessage(content='What is the weather today?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='I’m sorry, but I can’t provide today’s weather here.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#   HumanMessage(content='What is the weather today?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='I’m sorry, but I can’t help with today’s weather here.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])],
#  'coordinator_agent': {'iteration': 5,
#   'final_answer': True,
#   'plan': [],
#   'next_agent': ''},
#  'answer': 'I’m sorry, but I can’t help with today’s weather here.'}

# %%
print(result_1["answer"])
# Out:
# I’m sorry, but I can’t help with today’s weather here.

# %%
initial_state = {
    "messages": [HumanMessage(content="Can I get some earphones and a laptop? Could you also fetch some user reviews about durability of each item suggested?")]
}
config = {
    "configurable": {
        "thread_id": "0000000000002002"
    }
}

with PostgresSaver.from_conn_string(
    "postgresql://langgraph_user:langgraph_password@localhost:5433/langgraph_db"
) as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["values"]
    ):
        result_2 = chunk[1]

# %%
result_2
# Out:
# {'messages': [HumanMessage(content='Can I get some earphones and a laptop? Could you also fetch some user reviews about durability of each item suggested?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content=[{'id': 'rs_0040172e050079c7006a7123080ba0819e9079cd1c5553b85b', 'summary': [], 'type': 'reasoning', 'content': [], 'encrypted_content': 'gAAAAABqcSMIDHSjoX2MAsHaVkuYWlTjudK6uIoCfFWlIuuVqWSHm-II-fP-33wq4iDNSKJ2FnL7fVUhUbzHG9EOJbBiG0s-787ATiyDl4i0BPLYMZbUh8xvcWuTl15fzAkOJhCcziwBanXeB5hrfMUmdq0mYFTOfRxroBojbk6B_3FogoX_z-V2MaoreQg0BUzsFW4vQB677Vuk8Ztp83Por78VsQBvQp76r-l2OMuXuD11hYcxYytIQtuI04rRRmaJBoVuQJ7-9ouey-fyUtjDhECn_IbSr8Jj1bDcutWNPZO9cSW8laLegCp_-pyLLpJy6FThpEWQM3kl9xnt2wgZiqIRaT6wJtCHiFAn3iX8bPjFQizbIUtMJZVo15bkR8xRzE8T_8AXo675KXuubIqG_u12Ej5KEMjP2rjDbU68fVziM_SfIU1uOqUEOfbuVewl-rc5egdxsT7E8J3UYsL8PWrBiERchECYSxNThJ7upiosuP6DxAkHHlBWK38D12cSeDrhM_O4Y-BQrQp7cAFmN5_VyIHZa-QysxU7P9JX7B6a-F_dz2G0gT00TXd-Yp_binFst-Dzo4ANgBg0Gq2hnQ7aqkSQQIbSrI
 'type': 'function_call', 'id': 'fc_0040172e050079c7006a71230afb28819e96faf1dfe4a6c26c', 'status': 'completed'}], additional_kwargs={}, response_metadata={'id': 'resp_0040172e050079c7006a7123099fe8819e9a242306ed2c889d', 'created_at': 1785799433.0, 'metadata': {}, 'model': 'gpt-5.4-mini-2026-03-17', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17'}, id='resp_0040172e050079c7006a7123099fe8819e9a242306ed2c889d', tool_calls=[{'name': 'get_formatted_reviews_context', 'args': {'query': 'durability', 'parent_asins': ['B000026YEB', 'B0BLZG2YMG', 'B09TRPFBD2', 'B0BG2ZDW9P', 'B0B7W843W2'], 'top_k': 20}, 'id': 'call_u1nlPfOzkdIUzgC4QwkTfgrI', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1069, 'output_tokens': 187, 'total_tokens': 1256, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 114}}),
#   ToolMessage(content='Reviews collection Amazon-reviews-collection-01 is not available locally. Run notebooks/week_4/02-Multiple-Tools.ipynb to create it.', name='get_formatted_reviews_context', tool_call_id='call_u1nlPfOzkdIUzgC4QwkTfgrI'),
#   AIMessage(content='Here are some available products I found:\n\nEarphones\n- Pod (ID: B000026YEB) — rating 4.7\n- Listen To The Music (ID: B0BLZG2YMG) — rating 4.7\n- Reach the Beach Translucent Gold Audiophile (ID: B09TRPFBD2) — rating 4.8\n\nLaptop\n- Love (ID: B0BG2ZDW9P) — rating 4.8\n- Pod (ID: B000026YEB) — rating 4.7\n- Wish (ID: B0B7W843W2) — rating 4.7\n\nI tried to fetch user reviews focused on durability, but the reviews collection isn’t available locally right now, so I can’t verify durability feedback for these items from user reviews. If you want, I can still help you compare the available products by rating or search for a narrower type of earphones or laptop.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#   AIMessage(content='Here are the available products I found:\n\nEarphones\n- Pod (ID: B000026YEB) — rating 4.7\n- Listen To The Music (ID: B0BLZG2YMG) — rating 4.7\n- Reach the Beach Translucent Gold Audiophile (ID: B09TRPFBD2) — rating 4.8\n\nLaptop\n- Love (ID: B0BG2ZDW9P) — rating 4.8\n- Pod (ID: B000026YEB) — rating 4.7\n- Wish (ID: B0B7W843W2) — rating 4.7\n\nI wasn’t able to retrieve user reviews about durability because the reviews collection isn’t available locally right now. If you’d like, I can still help you choose among these available products based on rating or you can ask for a narrower search.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#   AIMessage(content='Here are the available products I found:\n\nEarphones\n- Pod (ID: B000026YEB) — rating 4.7\n- Listen To The Music (ID: B0BLZG2YMG) — rating 4.7\n- Reach the Beach Translucent Gold Audiophile (ID: B09TRPFBD2) — rating 4.8\n\nLaptop\n- Love (ID: B0BG2ZDW9P) — rating 4.8\n- Pod (ID: B000026YEB) — rating 4.7\n- Wish (ID: B0B7W843W2) — rating 4.7\n\nI couldn’t fetch user reviews about durability because the reviews collection isn’t available locally right now, so I can’t verify durability feedback for these items from user reviews.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#   AIMessage(content='Here are the available products I found:\n\nEarphones\n- Pod (ID: B000026YEB) — rating 4.7\n- Listen To The Music (ID: B0BLZG2YMG) — rating 4.7\n- Reach the Beach Translucent Gold Audiophile (ID: B09TRPFBD2) — rating 4.8\n\nLaptop\n- Love (ID: B0BG2ZDW9P) — rating 4.8\n- Pod (ID: B000026YEB) — rating 4.7\n- Wish (ID: B0B7W843W2) — rating 4.7\n\nI couldn’t fetch user reviews about durability because the reviews collection isn’t available locally right now, so I can’t verify durability feedback for these items from user reviews.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#   HumanMessage(content='Oh I love HP 15.6 HD Business Laptop? could you add 3 of these to my cart?', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='Oh I love HP 15.6 HD Business Laptop? could you add 3 of these to my cart?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content=[{'id': 'rs_0040172e050079c7006a712321aa74819eba9ad847ce8808d1', 'summary': [], 'type': 'reasoning', 'content': [], 'encrypted_content': 'gAAAAABq
', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1990, 'output_tokens': 163, 'total_tokens': 2153, 'input_token_details': {'cache_read': 1408}, 'output_token_details': {'reasoning': 125}}),
#   HumanMessage(content='Can I get some earphones and a laptop? Could you also fetch some user reviews about durability of each item suggested?', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='Can I get some earphones and a laptop? Could you also fetch some user reviews about durability of each item suggested?', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='Can I get some earphones and a laptop? Could you also fetch some user reviews about durability of each item suggested?', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='Can I get some earphones and a laptop? Could you also fetch some user reviews about durability of each item suggested?', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='Can I get some earphones and a laptop? Could you also fetch some user reviews about durability of each item suggested?', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='Can I get some earphones and a laptop? Could you also fetch some user reviews about durability of each item suggested?', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='Can I get some earphones and a laptop? Could you also fetch some user reviews about durability of each item suggested?', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='Can I get some earphones and a laptop? Could you also fetch some user reviews about durability of each item suggested?', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='Can I get some earphones and a laptop? Could you also fetch some user reviews about durability of each item suggested?', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='Can I get some earphones and a laptop? Could you also fetch some user reviews about durability of each item suggested?', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='Can I get some earphones and a laptop? Could you also fetch some user reviews about durability of each item suggested?', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='Oh I love HP 15.6 HD Business Laptop? could you add 3 of these to my cart?', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='Oh I love HP 15.6 HD Business Laptop? could you add 3 of these to my cart?', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='Oh I love HP 15.6 HD Business Laptop? could you add 3 of these to my cart?', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='Can I get some earphones and a laptop? Could you also fetch some user reviews about durability of each item suggested?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='Here are the available products I found:\n\nEarphones\n- Pod (ID: B000026YEB) — rating 4.7\n- Listen To The Music (ID: B0BLZG2YMG) — rating 4.7\n- Reach the Beach Translucent Gold Audiophile (ID: B09TRPFBD2) — rating 4.8\n\nLaptop\n- Love (ID: B0BG2ZDW9P) — rating 4.8\n- Pod (ID: B000026YEB) — rating 4.7\n- Wish (ID: B0B7W843W2) — rating 4.7\n\nI couldn’t fetch user reviews about durability because the reviews collection isn’t available locally right now, so I can’t verify durability feedback for these items from user reviews. If you want, I can still help you choose among these available products based on rating or search for a narrower type of earphones or laptop.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])],
#  'product_qna_agent': {'iteration': 1, 'final_answer': True},
#  'shopping_cart_agent': {'iteration': 5, 'final_answer': False},
#  'coordinator_agent': {'iteration': 5,
#   'final_answer': False,
#   'plan': [{'agent': 'product_qna_agent',
#     'task': 'Find a few earphones and laptop product suggestions for the user, and gather user-review evidence specifically about durability for each suggested item. Return the product IDs, names/descriptions, ratings, and any durability review snippets or a clear note if reviews are unavailable.'}],
#   'next_agent': 'product_qna_agent'},
#  'answer': '',
#  'references': [{'id': 'B000026YEB', 'description': 'Pod'},
#   {'id': 'B0BLZG2YMG', 'description': 'Listen To The Music'},
#   {'id': 'B09TRPFBD2',
#    'description': 'Reach the Beach Translucent Gold Audiophile'},
#   {'id': 'B0BG2ZDW9P', 'description': 'Love'},
#   {'id': 'B0B7W843W2', 'description': 'Wish'}],
#  'user_id': '0000000000002002',
#  'cart_id': '0000000000002002'}

# %%
print(result_2["answer"])

# %%
initial_state = {
    "messages": [HumanMessage(content="Oh I love HP 15.6 HD Business Laptop? could you add 3 of these to my cart?")],
    "user_id": "0000000000002002",
    "cart_id": "0000000000002002"
}
config = {
    "configurable": {
        "thread_id": "0000000000002002"
    }
}

with PostgresSaver.from_conn_string(
    "postgresql://langgraph_user:langgraph_password@localhost:5433/langgraph_db"
) as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["values"]
    ):
        result_3 = chunk[1]

# %%
print(result_3["answer"])

# %%
initial_state = {
    "messages": [HumanMessage(content="Oh I love HP 15.6 HD Business Laptop? could you add 3 of these to my cart?")],
    "user_id": "0000000000002002",
    "cart_id": "0000000000002002",
    "coordinator_agent": {
        "iteration": 0,
        "final_answer": False,
        "plan": [],
        "next_agent": ""
    },
    "product_qna_agent": {
        "iteration": 0,
        "final_answer": False
    },
    "shopping_cart_agent": {
        "iteration": 0,
        "final_answer": False
    }
}
config = {
    "configurable": {
        "thread_id": "0000000000002002"
    }
}

with PostgresSaver.from_conn_string(
    "postgresql://langgraph_user:langgraph_password@localhost:5433/langgraph_db"
) as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["values"]
    ):
        result_4 = chunk[1]

# %%
print(result_4["answer"])
# Out:
# Added 3 more of HP 15.6 HD Business Laptop to your cart. You now have 6 total, with a cart total of $149.94.

# %%
initial_state = {
    "messages": [HumanMessage(content="Can I get some earphones and a laptop? Could you also fetch some user reviews about durability of each item suggested and then add the item which seams to be the most reliable to my cart?")],
    "user_id": "0000000000002003",
    "cart_id": "0000000000002003",
    "coordinator_agent": {
        "iteration": 0,
        "final_answer": False,
        "plan": [],
        "next_agent": ""
    },
    "product_qna_agent": {
        "iteration": 0,
        "final_answer": False
    },
    "shopping_cart_agent": {
        "iteration": 0,
        "final_answer": False
    }
}
config = {
    "configurable": {
        "thread_id": "0000000000002003"
    }
}

with PostgresSaver.from_conn_string(
    "postgresql://langgraph_user:langgraph_password@localhost:5433/langgraph_db"
) as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["values"]
    ):
        result_5 = chunk[1]

# %%
print(result_5["answer"])

# %% [markdown]
# ### Check if the Coordinator loop with the QnA agent persists.

# %%
initial_state = {
    "messages": [HumanMessage(content="Can I get some earphones and a laptop? Could you also fetch some user reviews about durability of each item suggested?")],
    "user_id": "0000000000002004",
    "cart_id": "0000000000002004",
    "coordinator_agent": {
        "iteration": 0,
        "final_answer": False,
        "plan": [],
        "next_agent": ""
    },
    "product_qna_agent": {
        "iteration": 0,
        "final_answer": False
    },
    "shopping_cart_agent": {
        "iteration": 0,
        "final_answer": False
    }
}
config = {
    "configurable": {
        "thread_id": "0000000000002004"
    }
}

with PostgresSaver.from_conn_string(
    "postgresql://langgraph_user:langgraph_password@localhost:5433/langgraph_db"
) as checkpointer:

    graph = workflow.compile(checkpointer=checkpointer)

    for chunk in graph.stream(
        initial_state,
        config=config,
        stream_mode=["values"]
    ):
        result_6 = chunk[1]
